# %% [markdown]
# **1. Matplotlib의 pyplot 모듈을 사용하여 시각화해봅니다.**

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# #### 1) Figure과 facecolor을 활용하여 plot을 생성하기.

# %%
# figsize 크기가 가로 4, 세로 4이며 배경색이 노란색인 plot을 반환하세요.

plt.figure(figsize=(4,4),facecolor='yellow')

plt.plot([1,2,3], [2,4,6])
plt.show()

# %% [markdown]
# #### 2) Axes 객체를 이용하여 선 그래프 그리기.

# %%
# plt.subplots를 이용하여 Figure와 Axes 객체를 함께 가져옵니다. Figsize는 (4,4)로 설정
fig, ax = plt.subplots(figsize=(4, 4))

# Axes 객체의 plot()을 이용하여 선 그래프를 그립니다.
ax.plot([1,2,3],[2,4,6])


# Axes 객체의 set_title()을 이용하여 선 그래프의 타이틀을 자유롭게 설정하세요.
ax.set_title('ax_graph')

plt.show()

# %% [markdown]
# #### 3) 여러 개의 plot을 subplot들을 생성하기.

# %%
# 두 개의 subplot, 즉 두 개의 Axes를 생성하되 열 방향으로 두 개를 배치함.
# 또한 전체 크기가 가로 6, 세로 3인 Figure 생성.
fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(6,3))

# %% [markdown]
# #### 4) pyplot의 plot() 함수를 이용하여 간단한 직선 그래프 그리기.

# %%
# x_value에 [1,2,3,4], y_value에 [2,4,5,8]을 가지는 파이썬 리스트를 생성하고
# plot()에 인자로 입려하여 간단한 직선 그래프를 만들어 보세요.
# color 인자를 설정하여 선의 색깔을 녹색으로 변경합니다.
x_value=[1,2,3,4]
y_value=[2,4,5,8]
plt.plot(x_value,y_value,color='green')

# %% [markdown]
# #### 5) 축의 눈금값 회전, 범례 설정하기.

# %%
# x 좌표 값을 0~99까지 100개로 설정.
x_value=np.arange(0,100)

# y 좌표 값은 개별 x좌표 값을 2배로 해서 100개로 설정.
y_value=2*x_value

plt.plot(x_value, y_value, color='green')

# x축 눈금값을 90도로 회전
plt.xticks(rotation=90)
# Out:
# (array([-20.,   0.,  20.,  40.,  60.,  80., 100., 120.]),
#  [Text(-20.0, 0, '−20'),
#   Text(0.0, 0, '0'),
#   Text(20.0, 0, '20'),
#   Text(40.0, 0, '40'),
#   Text(60.0, 0, '60'),
#   Text(80.0, 0, '80'),
#   Text(100.0, 0, '100'),
#   Text(120.0, 0, '120')])

# %%
x_value_01 = np.arange(1,10)
y_value_01 = 2*x_value_01

# 마커를 포함한 빨간색 대시 선 그래프를 그리고, label은 'red line'으로 설정
plt.plot(x_value_01,y_value_01,'-o',color='red',label='red line')

# x값에 따른 y값을 나타내는 초록색 막대 그래프를 그리고 label은 'bar plot'으로 설정
plt.bar(x_value_01,y_value_01,color='green',label='bar plot')

plt.xlabel('x axis')
plt.ylabel('y axis')

# 개별 plot들의 label로 설정된 문자열을 범례로 표시
plt.legend()
plt.show()

# %% [markdown]
# #### 6) 여러 개의 subplot을 이용해 개별 그래프를 subplot별로 시각화하기

# %%
# 다음 plot과 같은 형태로 출력하세요. figsize는 (6,3)
plt.subplots(nrows=1,ncols=2,figsize=(6,3))
# Out:
# (<Figure size 600x300 with 2 Axes>, array([<Axes: >, <Axes: >], dtype=object))

# %%
x_value_01 = np.arange(1,10)
x_value_02 = np.arange(1,20)
y_value_01 = 2 * x_value_01
y_value_02 = 2 * x_value_02

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(6,3))

# 개별 Axes 객체를 이용하여 선 그래프와 막대그래프를 그립니다.
# ?를 채워넣으세요
ax[0].plot(x_value_01, y_value_01, color='red', marker='o', linestyle='dashed', label='red line')
ax[1].bar(x_value_02, y_value_02, color='green', label='bar plot')

# 개별 Axes 객체 각각에 X축명을 설정.
ax[0].set_xlabel('ax[0] x axis')
ax[1].set_xlabel('ax[1] x axis')

# 개별 Axes 객체 각각에 범례 설정
ax[0].legend()
ax[1].legend()

# %% [markdown]
# **2. Seaborn을 사용하여 시각화해봅니다.**

# %% [markdown]
# #### 0) 데이터 불러오기(실행해 주세요.)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

titanic_df=pd.read_csv("titanic.csv")
titanic_df = titanic_df.dropna(subset=["Embarked"])
titanic_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### 1) 여러가지 컬럼들로 시각화하기
# subplot으로 2*3 개의 subplots만들기 figsize=(14, 8)
#
# (0, 0) age의 히스토그램을 시각화, survived로 색깔을 달리하기, 연속 확률분포 곡선도 표현하기
# (0, 1) pclass에 따른 age를 수평 barplot으로 만들기, 99% 신뢴구간을 표시하기
# (0, 2) pclass에 따른 survived의 합을 barplot으로 만들기, sex로 색깔을 달리하기(신뢰구간 표시 x)
# (1, 0) embarked에 따른 fare의 boxplot 만들기, Pclass로 색깔을 달리하기
# (1, 1) survived에 따른 age의 violin plot 만들기, sex로 색깔을 달리하기
# (1, 2) age에 따른 fare의 scatter plot 만들기, Survived로 색깔을 달리하고 Embarked로 모양을 달리해 표현하기

# %%
fig, axs= plt.subplots(nrows=3, ncols=2, figsize=(14,8))

sns.histplot(x='age',hue='survived', data=titanic_df, ax=axs[0,0])
sns.barplot(x='pclass',y='age',ci=99, data=titanic_df, ax=axs[0,1])
sns.barplot(x='pclass',y='survived',hue='sex',estimator=np.sum, data=titanic_df, ax=axs[0, 2])
sns.boxplot(x='embarked',y='fare',hue='pclass', data=titanic_df, ax=axs[1,0])
sns.violinplot(x='survived',y='age',hue='sex', data=titanic_df, ax=axs[1,1])
sns.scatterplot(x='age',y='fare',hue='survived',style='embarked',data=titanic_df, ax=axs[1, 2])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 3
#       1 fig, axs= plt.subplots(nrows=3, ncols=2, figsize=(14,8))
# ----> 3 sns.histplot(x='age',hue='survived', data=titanic_df, ax=axs[0,0])
#       4 sns.barplot(x='pclass',y='age',ci=99, data=titanic_df, ax=axs[0,1])
#       5 sns.barplot(x='pclass',y='survived',hue='sex',estimator=np.sum, data=titanic_df, ax=axs[0, 2])
#
# File ~\anaconda3\Lib\site-packages\seaborn\distributions.py:1395, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1374 def histplot(
#    1375     data=None, *,
#    1376     # Vector variables
#    (...)
#    1392     **kwargs,
#    1393 ):
# -> 1395     p = _DistributionPlotter(
#    1396         data=data,
#    1397         variables=_DistributionPlotter.get_semantics(locals())
#    1398     )
#    1400     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#    1402     if ax is None:
#
# File ~\anaconda3\Lib\site-packages\seaborn\distributions.py:113, in _DistributionPlotter.__init__(self, data, variables)
#     107 def __init__(
#     108     self,
#     109     data=None,
#     110     variables={},
#     111 ):
# --> 113     super().__init__(data=data, variables=variables)
#
# File ~\anaconda3\Lib\site-packages\seaborn\_oldcore.py:640, in VectorPlotter.__init__(self, data, variables)
#     635 # var_ordered is relevant only for categorical axis variables, and may
#     636 # be better handled by an internal axis information object that tracks
#     637 # such information and is set up by the scale_* methods. The analogous
#     638 # information for numeric axes would be information about log scales.
#     639 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 640 self.assign_variables(data, variables)
#     642 for var, cls in self._semantic_mappings.items():
#     643
#     644     # Create the mapping function
#     645     map_func = partial(cls.map, plotter=self)
#
# File ~\anaconda3\Lib\site-packages\seaborn\_oldcore.py:701, in VectorPlotter.assign_variables(self, data, variables)
#     699 else:
#     700     self.input_format = "long"
# --> 701     plot_data, variables = self._assign_variables_longform(
#     702         data, **variables,
#     703     )
#     705 self.plot_data = plot_data
#     706 self.variables = variables
#
# File ~\anaconda3\Lib\site-packages\seaborn\_oldcore.py:938, in VectorPlotter._assign_variables_longform(self, data, **kwargs)
#     933 elif isinstance(val, (str, bytes)):
#     934
#     935     # This looks like a column name but we don't know what it means!
#     937     err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 938     raise ValueError(err)
#     940 else:
#     941
#     942     # Otherwise, assume the value is itself data
#     943
#     944     # Raise when data object is present and a vector can't matched
#     945     if isinstance(data, pd.DataFrame) and not isinstance(val, pd.Series):
#
# ValueError: Could not interpret value `age` for parameter `x`

# %% [markdown]
# #### 2) 상관 히트맵 만들기
#
# 1. 숫자형 컬럼만 살리기
#
# 2. 상관계수의 숫자를 소수점 두번째 자리까지 표시하기

# %%
titanic_df_numeric=titanic_df.select_dtypes(include='number')

sns.heatmap(np.round(titanic_df_numeric.corr(),2))

plt.show()
